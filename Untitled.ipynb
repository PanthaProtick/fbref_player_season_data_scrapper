# %%
import pandas as pd

# %%
df=pd.read_csv("messi11-12.csv")
df
# Out:
#           Date  Day          Comp               Round Venue Result  \
# 0   2011-08-29  Mon       La Liga         Matchweek 2  Home  W 5–0
# 1   2011-09-10  Sat       La Liga         Matchweek 3  Away  D 2–2
# 2   2011-09-13  Tue  Champions Lg         Group stage  Home  D 2–2
# 3   2011-09-17  Sat       La Liga         Matchweek 4  Home  W 8–0
# 4   2011-09-21  Wed       La Liga         Matchweek 5  Away  D 2–2
# 5   2011-09-24  Sat       La Liga         Matchweek 6  Home  W 5–0
# 6   2011-09-28  Wed  Champions Lg         Group stage  Away  W 5–0
# 7   2011-10-02  Sun       La Liga         Matchweek 7  Away  W 1–0
# 8   2011-10-07  Fri           WCQ  WCQ — CONMEBOL (M)  Home  W 4–1
# 9   2011-10-11  Tue           WCQ  WCQ — CONMEBOL (M)  Away  L 0–1
# 10  2011-10-15  Sat       La Liga         Matchweek 8  Home  W 3–0
# 11  2011-10-19  Wed  Champions Lg         Group stage  Home  W 2–0
# 12  2011-10-22  Sat       La Liga         Matchweek 9  Home  D 0–0
# ...
